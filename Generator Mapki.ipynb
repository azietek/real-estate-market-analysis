# %%
import folium #Umożliwia tworzenie interaktywnych map w języku Python
from IPython.display import display # Umożliwia wyświetlanie interaktywnych wyników w środowisku IPython
from geopy.geocoders import Nominatim #służy do geokodowania, czyli przekształcania adresów lub miejsc na współrzędne geograficzne.
import requests
import polyline # używana do reprezentacji tras na mapie.
import pandas as pd
from folium.plugins import MarkerCluster, FeatureGroupSubGroup

# %%
df = pd.read_csv('./sample4map2.csv', index_col=0)

# %%
df
# Out:
#                                       nazwa ogloszenia        cena  \
# 82              2-pokojowe mieszkanie 38m2 + 2 ogródki  509 145 zł
# 14   PROMOCJA | NajlepszaCENA |SuperUstawne|Sprawdź...  539 000 zł
# 62    2-pokojowe mieszkanie 40m2 + loggia Bez Prowizji  522 329 zł
# 96   OSTATNIE|NajlepszaCena|promocja|NowaInwestycja...  469 000 zł
# 60                     Okazja 2 pok , Centrum, Wrocław  403 000 zł
# 110  Ostatnie| Nowe Budownictwo | Balkon | Obejrzyj...  453 000 zł
# 29   OSTATNIE NAROŻNE|Garderoba| DużeOkna| Sprawdź|...  489 000 zł
# 71          Okolice ul. Żelaznej Inwestycja/COmiejskie  518 000 zł
# 7    PROMOCJA | Super Ustawne | Nowa Inwestycja | HIT!  488 400 zł
# 112   PROMOCJA | NajlepszaCENA | OstatnieSztuki | HIT!  329 000 zł
#
#                                                   opis  \
# 82                                    Wirtualny spacer
# 14   Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
# 62                                    Wirtualny spacer
# 96   Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
# 60   Sprzedam mieszkanie 37m2 we Wrocławiu. Mieszka...
# 110  Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
# 29   Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
# 71   Na sprzedaż dwupokojowe, zadbane oraz odświeżo...
# 7    Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
# 112  Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
#
#                                            lokalizacja    dzielnica  \
# 82   ul. Konińska, Leśnica, Fabryczna, Wrocław, dol...    Fabryczna
# 14   ul. Ignacego Mościckiego, Bieńkowice, Krzyki, ...       Krzyki
# 62   ul. Konińska, Leśnica, Fabryczna, Wrocław, dol...    Fabryczna
# 96   ul. Ignacego Mościckiego, Bieńkowice, Krzyki, ...       Krzyki
# 60   ul. Nowowiejska, Ołbin, Śródmieście, Wrocław, ...  Śródmieście
# 110  ul. Woskowa, Brochów, Krzyki, Wrocław, dolnośl...       Krzyki
# 29   ul. Woskowa, Brochów, Krzyki, Wrocław, dolnośl...       Krzyki
# 71          Gajowice, Fabryczna, Wrocław, dolnośląskie    Fabryczna
# 7    ul. Woskowa, Brochów, Krzyki, Wrocław, dolnośl...       Krzyki
# 112  ul. Ignacego Mościckiego, Bieńkowice, Krzyki, ...       Krzyki
#
#                              ulica        zametr  pokoje powierzchnia  \
# 82               Konińska, Wrocław  13 099 zł/m²     2.0     38,87 m²
# 14   Ignacego Mościckiego, Wrocław   7 985 zł/m²     4.0      67,5 m²
# 62               Konińska, Wrocław  12 768 zł/m²     2.0     40,91 m²
# 96   Ignacego Mościckiego, Wrocław   8 058 zł/m²     3.0      58,2 m²
# 60            Nowowiejska, Wrocław  10 605 zł/m²     2.0        38 m²
# 110               Woskowa, Wrocław   9 867 zł/m²     3.0     45,91 m²
# 29                Woskowa, Wrocław   9 839 zł/m²     3.0      49,7 m²
# 71                 Rudzka, Wrocław  14 153 zł/m²     2.0      36,6 m²
# 7                 Woskowa, Wrocław   9 947 zł/m²     3.0      49,1 m²
# 112  Ignacego Mościckiego, Wrocław   9 014 zł/m²     2.0      36,5 m²
#
#                     wysposażenie  ...                  typ forma wlasnosci  \
# 82                           NaN  ...                  NaN  pełna własność
# 14               brak informacji  ...  biuro nieruchomości  pełna własność
# 62                           NaN  ...                  NaN  pełna własność
# 96               brak informacji  ...  biuro nieruchomości  pełna własność
# 60   piekarnik, kuchenka, pralka  ...  biuro nieruchomości             NaN
# 110              brak informacji  ...  biuro nieruchomości  pełna własność
# 29               brak informacji  ...  biuro nieruchomości  pełna własność
# 71               brak informacji  ...  biuro nieruchomości  pełna własność
# 7                brak informacji  ...  biuro nieruchomości  pełna własność
# 112              brak informacji  ...  biuro nieruchomości  pełna własność
#
#     stan wykonczenia balkon/ogrod/taras        miejsce parkingowe ogrzewanie  \
# 82    do wykończenia     taras, ogródek  garaż/miejsce parkingowe        NaN
# 14               NaN      balkon, taras  garaż/miejsce parkingowe   miejskie
# 62    do wykończenia                NaN  garaż/miejsce parkingowe        NaN
# 96               NaN      balkon, taras  garaż/miejsce parkingowe   miejskie
# 60   do zamieszkania                NaN  garaż/miejsce parkingowe        NaN
# 110              NaN      balkon, taras  garaż/miejsce parkingowe   miejskie
# 29               NaN      balkon, taras  garaż/miejsce parkingowe   miejskie
# 71               NaN             balkon                       NaN   miejskie
# 7                NaN      balkon, taras  garaż/miejsce parkingowe   miejskie
# 112              NaN      balkon, taras  garaż/miejsce parkingowe   miejskie
#
#          telefon                                               link  \
# 82   573 560 379  https://www.otodom.pl/pl/oferta/2-pokojowe-mie...
# 14   690 725 555  https://www.otodom.pl/pl/oferta/promocja-najle...
# 62   573 560 379  https://www.otodom.pl/pl/oferta/2-pokojowe-mie...
# 96   690 725 555  https://www.otodom.pl/pl/oferta/ostatnie-najle...
# 60   536 186 831  https://www.otodom.pl/pl/oferta/okazja-2-pok-c...
# 110  690 725 555  https://www.otodom.pl/pl/oferta/ostatnie-nowe-...
# 29   690 725 555  https://www.otodom.pl/pl/oferta/ostatnie-naroz...
# 71   698 666 308  https://www.otodom.pl/pl/oferta/okolice-ul-zel...
# 7    690 725 555  https://www.otodom.pl/pl/oferta/promocja-super...
# 112  690 725 555  https://www.otodom.pl/pl/oferta/promocja-najle...
#
#          Score ulica_dzielnica
# 82   10.000000          Rudzka
# 14    8.154165          Gajowa
# 62    6.260087          Rudzka
# 96    5.312112          Gajowa
# 60    4.643208         Kossaka
# 110   2.792873          Gajowa
# 29    2.489565          Gajowa
# 71    2.456037          Rudzka
# 7     2.335822          Gajowa
# 112   2.243598          Gajowa
#
# [10 rows x 24 columns]

# %%
def rysowanie_mapki(df):
    '''Funkcja przyjmująca df, ktory musi zawierac kolumne ulice oraz Score. IM jako punkt startowy jest dopisywany automatycznie.
    Df w srodku sortuje sie wzgledem punktacji i ustawia kolorki ikonki itd odpowiednie dla oferty. 

    Zwraca liste w której pierwszy element to lista tekstów dotyczacych długosci podrozy, a drugi element to
    dfmapke z ofertami, ktore zostaly uzyte. Mapka wyświetla się automatycznie i tworzy plik html w miejscu gdzie jest plik z kodem, na mapie mamy
    sciezke miedzy glownymi ofertami + dolozone sa oferty ktore sa 'po drodze'. '''
    
    df=pd.concat([df,pd.DataFrame(data=[['plac Grunwaldzki 2, Wrocław',999]],columns=['ulica','Score'])],ignore_index=True)  #dodanie im jako startu
    kolorki = ['blue','green','green','green','orange','orange','orange','orange']
    ikonki = ['search','home','home','home','map-marker','map-marker','map-marker','map-marker']
    df=df.sort_values(by='Score',ascending=False)
    df=df[0:8]
    df['kolor']=kolorki
    df['ikona']=ikonki
    wykorzystane=df[1:4]
    mapbox_api_key = ''

    geolocator = Nominatim(user_agent="my_geocoder") #definiujemy usługę geokodowania
    
    loc = geolocator.geocode('Wrocław')
    loc = [loc.latitude,loc.longitude]
    
    map_wroclaw = folium.Map(loc, zoom_start=12, control_scale=True)
    # Dodawanie warstwy mapbox do mapy
    folium.TileLayer(
        tiles=f'https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/256/{{z}}/{{x}}/{{y}}@2x?access_token={mapbox_api_key}',
        attr='Mapbox',
        name='Mapbox Streets',
        overlay=True
    ).add_to(map_wroclaw)
    

    coordinates=[]
    adres = []
    	
    marker_cluster = MarkerCluster().add_to(map_wroclaw)
    
    for i in range(0,8): #stawianie 3 glownych punktow i IM, i zbieranie koordynatow wszystkich
        adres.append(df.iloc[i]['ulica'])
        kolor = df.iloc[i]['kolor']
        ikona = df.iloc[i]['ikona']
        location = geolocator.geocode(adres[i])
        if i <= 3: #zeby na razie dodalo tylko im i 3 glowne punkty
            folium.Marker(location=[location.latitude, location.longitude], popup=adres[i],icon=folium.Icon(color=kolor, icon=ikona)).add_to(marker_cluster)
        coordinates.append([location.longitude,location.latitude])
    
    
    #szukanie optymalnej drogi miedzy im a trzema najlepszymi
    profile = 'driving'
    optimized_trips_url = f'https://api.mapbox.com/optimized-trips/v1/mapbox/{profile}/{coordinates[0][0]},{coordinates[0][1]};{coordinates[1][0]},{coordinates[1][1]};{coordinates[2][0]},{coordinates[2][1]};{coordinates[3][0]},{coordinates[3][1]}?access_token={mapbox_api_key}'
    response = requests.get(optimized_trips_url)
    data_opt = response.json()
    dystans = round(data_opt['trips'][0]['distance']/1000,2)
    czas = round(data_opt['trips'][0]['duration']/60)
    #ponizej sprawdzamy dla pozostalych 4 opcjonlanych miejsc czy dolozenie ich 
    #zwiekszy czas przejazdu o poonad 20% - jesli tak olewamy, jesli nie dokladamy.
    czas_dodatkowy=[]
    for i in range(4,8):
        profile = 'driving'
        optimized_trips_url = f'https://api.mapbox.com/optimized-trips/v1/mapbox/{profile}/{coordinates[0][0]},{coordinates[0][1]};{coordinates[1][0]},{coordinates[1][1]};{coordinates[2][0]},{coordinates[2][1]};{coordinates[3][0]},{coordinates[3][1]};{coordinates[i][0]},{coordinates[i][1]}?access_token={mapbox_api_key}'
        response = requests.get(optimized_trips_url)
        data_opt = response.json()
        if data_opt['trips'][0]['duration']/60 <= czas*1.2:
            czas_dodatkowy.append([data_opt['trips'][0]['duration']/60 - czas,i])
    #sprawdzanie ile znalazlo i tworzenie z nimi nowej drogi
    #wpisywanie wspolrzednych do stringa i wrzucanie znacznikow dodatkowych miejsc na mape
    pozostale = '' 
    for i in range (0,len(czas_dodatkowy)):
        wykorzystane=pd.concat([wykorzystane,df.iloc[czas_dodatkowy[i][1]].to_frame().T],ignore_index=True) 
        pozostale = pozostale + ';' +str(coordinates[czas_dodatkowy[i][1]][0])+','+str(coordinates[czas_dodatkowy[i][1]][1])
        folium.Marker(location=[coordinates[czas_dodatkowy[i][1]][1], coordinates[czas_dodatkowy[i][1]][0]],popup=adres[czas_dodatkowy[i][1]],icon=folium.Icon(color='orange', icon='map-marker')).add_to(marker_cluster)
    
    #oficjalna trasa z punktami ktore sie oplaca
    optimized_trips_url = f'https://api.mapbox.com/optimized-trips/v1/mapbox/{profile}/{coordinates[0][0]},{coordinates[0][1]};{coordinates[1][0]},{coordinates[1][1]};{coordinates[2][0]},{coordinates[2][1]};{coordinates[3][0]},{coordinates[3][1]}{pozostale}?access_token={mapbox_api_key}'
    
    #reszta rzeczy zeby mapa sie pojawila i stringi z informacja ile sie jedzie bez / z punktami dodatkowymi.
    response = requests.get(optimized_trips_url)
    data_opt = response.json()
    coor = polyline.decode(data_opt['trips'][0]['geometry'])
    folium.PolyLine(locations=coor, color='blue').add_to(map_wroclaw)
    teksty = [
    f"Odległość trasy bez dodatkowych ofert: ok. {dystans} km",
    f"Czas podróży bez dodatkowych ofert: ok. {czas} min",
    f"Odległość trasy: ok. {round(data_opt['trips'][0]['distance']/1000,2)} km",
    f"Czas podróży: ok. {round(data_opt['trips'][0]['duration']/60)} min"
    ]
    
    
    map_wroclaw.save('map.html')
    display(map_wroclaw)
    return [teksty,wykorzystane]

# %%
rys=rysowanie_mapki(df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5f03584b5115f713ee35f322ee71be2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5f03584b5115f713ee35f322ee71be2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5f03584b5115f713ee35f322ee71be2 = L.map(
#                 &quot;map_c5f03584b5115f713ee35f322ee71be2&quot;,
#                 {
#                     center: [51.1089776, 17.0326689],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c5f03584b5115f713ee35f322ee71be2);
#
#
#
#
#
#             var tile_layer_0d33ae5cadc29e15ed8bb6db979f6113 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d33ae5cadc29e15ed8bb6db979f6113.addTo(map_c5f03584b5115f713ee35f322ee71be2);
#
#
#             var tile_layer_9e520df54b8d004b45145506dc3a6835 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1Ijoid3ljZW55IiwiYSI6ImNscnRraDBsajA3NXQyam5hdjloZTBoZ3EifQ.0gU_ozTPH70_eXfyfCAqkA&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9e520df54b8d004b45145506dc3a6835.addTo(map_c5f03584b5115f713ee35f322ee71be2);
#
#
#             var marker_cluster_7073585a0a2d1c465f3b6414f66409c7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_ed2df480b7fdb88914198e97959e1cb6 = L.marker(
#                 [51.1102016, 17.053976],
#                 {}
#             ).addTo(marker_cluster_7073585a0a2d1c465f3b6414f66409c7);
#
#
#             var icon_7d1e9dda725a2cdfd2042f01861485a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ed2df480b7fdb88914198e97959e1cb6.setIcon(icon_7d1e9dda725a2cdfd2042f01861485a8);
#
#
#         var popup_9630424c5497f8a5d1fa232bf7640199 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6780cc75b2d88dd48b6af70288c7e6c1 = $(`&lt;div id=&quot;html_6780cc75b2d88dd48b6af70288c7e6c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;plac Grunwaldzki 2, Wrocław&lt;/div&gt;`)[0];
#                 popup_9630424c5497f8a5d1fa232bf7640199.setContent(html_6780cc75b2d88dd48b6af70288c7e6c1);
#
#
#
#         marker_ed2df480b7fdb88914198e97959e1cb6.bindPopup(popup_9630424c5497f8a5d1fa232bf7640199)
#         ;
#
#
#
#
#             var marker_4fb81ddd3945a52c5c1d5721ace55da2 = L.marker(
#                 [51.1379271, 16.9212617],
#                 {}
#             ).addTo(marker_cluster_7073585a0a2d1c465f3b6414f66409c7);
#
#
#             var icon_154cafdaa8dcad7854424026a4c732ef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4fb81ddd3945a52c5c1d5721ace55da2.setIcon(icon_154cafdaa8dcad7854424026a4c732ef);
#
#
#         var popup_4da92434a7f1fa2a647f7382dd7d57a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bb01a8fb5f04bdd427d29000d90d3ff = $(`&lt;div id=&quot;html_1bb01a8fb5f04bdd427d29000d90d3ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Konińska, Wrocław&lt;/div&gt;`)[0];
#                 popup_4da92434a7f1fa2a647f7382dd7d57a6.setContent(html_1bb01a8fb5f04bdd427d29000d90d3ff);
#
#
#
#         marker_4fb81ddd3945a52c5c1d5721ace55da2.bindPopup(popup_4da92434a7f1fa2a647f7382dd7d57a6)
#         ;
#
#
#
#
#             var marker_5591689b13072dddb7deeb16a0b15fa0 = L.marker(
#                 [51.0507767, 17.0965116],
#                 {}
#             ).addTo(marker_cluster_7073585a0a2d1c465f3b6414f66409c7);
#
#
#             var icon_404355a3a2fe8a1c06bc9ebc0861235e

# %%
rys
# Out:
# [['Odległość trasy bez dodatkowych ofert: ok. 60.48 km',
#   'Czas podróży bez dodatkowych ofert: ok. 98 min',
#   'Odległość trasy: ok. 61.32 km',
#   'Czas podróży: ok. 104 min'],
#                                      nazwa ogloszenia        cena  \
#  0             2-pokojowe mieszkanie 38m2 + 2 ogródki  509 145 zł
#  1  PROMOCJA | NajlepszaCENA |SuperUstawne|Sprawdź...  539 000 zł
#  2   2-pokojowe mieszkanie 40m2 + loggia Bez Prowizji  522 329 zł
#  3  OSTATNIE|NajlepszaCena|promocja|NowaInwestycja...  469 000 zł
#  4                    Okazja 2 pok , Centrum, Wrocław  403 000 zł
#  5  Ostatnie| Nowe Budownictwo | Balkon | Obejrzyj...  453 000 zł
#  6  OSTATNIE NAROŻNE|Garderoba| DużeOkna| Sprawdź|...  489 000 zł
#
#                                                  opis  \
#  0                                   Wirtualny spacer
#  1  Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
#  2                                   Wirtualny spacer
#  3  Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
#  4  Sprzedam mieszkanie 37m2 we Wrocławiu. Mieszka...
#  5  Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
#  6  Pracujemy 7 dni w tygodniu. Zainteresowała Cię...
#
#                                           lokalizacja    dzielnica  \
#  0  ul. Konińska, Leśnica, Fabryczna, Wrocław, dol...    Fabryczna
#  1  ul. Ignacego Mościckiego, Bieńkowice, Krzyki, ...       Krzyki
#  2  ul. Konińska, Leśnica, Fabryczna, Wrocław, dol...    Fabryczna
#  3  ul. Ignacego Mościckiego, Bieńkowice, Krzyki, ...       Krzyki
#  4  ul. Nowowiejska, Ołbin, Śródmieście, Wrocław, ...  Śródmieście
#  5  ul. Woskowa, Brochów, Krzyki, Wrocław, dolnośl...       Krzyki
#  6  ul. Woskowa, Brochów, Krzyki, Wrocław, dolnośl...       Krzyki
#
#                             ulica        zametr pokoje powierzchnia  \
#  0              Konińska, Wrocław  13 099 zł/m²    2.0     38,87 m²
#  1  Ignacego Mościckiego, Wrocław   7 985 zł/m²    4.0      67,5 m²
#  2              Konińska, Wrocław  12 768 zł/m²    2.0     40,91 m²
#  3  Ignacego Mościckiego, Wrocław   8 058 zł/m²    3.0      58,2 m²
#  4           Nowowiejska, Wrocław  10 605 zł/m²    2.0        38 m²
#  5               Woskowa, Wrocław   9 867 zł/m²    3.0     45,91 m²
#  6               Woskowa, Wrocław   9 839 zł/m²    3.0      49,7 m²
#
#                    wysposażenie  ... stan wykonczenia balkon/ogrod/taras  \
#  0                          NaN  ...   do wykończenia     taras, ogródek
#  1              brak informacji  ...              NaN      balkon, taras
#  2                          NaN  ...   do wykończenia                NaN
#  3              brak informacji  ...              NaN      balkon, taras
#  4  piekarnik, kuchenka, pralka  ...  do zamieszkania                NaN
#  5              brak informacji  ...              NaN      balkon, taras
#  6              brak informacji  ...              NaN      balkon, taras
#
#           miejsce parkingowe ogrzewanie      telefon  \
#  0  garaż/miejsce parkingowe        NaN  573 560 379
#  1  garaż/miejsce parkingowe   miejskie  690 725 555
#  2  garaż/miejsce parkingowe        NaN  573 560 379
#  3  garaż/miejsce parkingowe   miejskie  690 725 555
#  4  garaż/miejsce parkingowe        NaN  536 186 831
#  5  garaż/miejsce parkingowe   miejskie  690 725 555
#  6  garaż/miejsce parkingowe   miejskie  690 725 555
#
#                                                  link     Score  \
#  0  https://www.otodom.pl/pl/oferta/2-pokojowe-mie...      10.0
#  1  https://www.otodom.pl/pl/oferta/promocja-najle...  8.154165
#  2  https://www.otodom.pl/pl/oferta/2-pokojowe-mie...  6.260087
#  3  https://www.otodom.pl/pl/oferta/ostatnie-najle...  5.312112
#  4  https://www.otodom.pl/pl/oferta/okazja-2-pok-c...  4.643208
#  5  https://www.otodom.pl/pl/oferta/ostatnie-nowe-...  2.792873
#  6  https://www.otodom.pl/pl/oferta/ostatnie-naroz...  2.489565
#
#    ulica_dzielnica   kolor       ikona
#  0          Rudzka   green        home
#  1          Gajowa   green        home
#  2          Rudzka   green        home
#  3          Gajowa  orange  map-marker
#  4         Kossaka  orange  map-marker
#  5          Gajowa  orange  map-marker
#  6          Gajowa  orange  map-marker
#
#  [7 rows x 26 columns]]
